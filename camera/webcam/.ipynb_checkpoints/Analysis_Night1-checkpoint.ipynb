# %%
import numpy as np
import cv2
import glob
import datetime
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pwd # under linux/mac
# Out:
# /Users/ethanweber/Documents/MIT_Classes/Sophomore_Spring2018/MAS.600/hackyodreamz/camera/webcam

# %%
cwd = "/Users/ethanweber/Documents/MIT_Classes/Sophomore_Spring2018/MAS.600/hackyodreamz/camera/webcam"

# %%
folder = "/data/4-29-2018_1"

# %%
path = cwd + folder

# %%
filenames = sorted(glob.glob(os.path.join(path,'*.png')))

# %%
images = []

# %%
for f in filenames:
    images.append(cv2.imread(f))

# %%
plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB), cmap='gray')

# %%
i = 0

# %%
gray1 = cv2.cvtColor(images[i], cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(images[i-1], cv2.COLOR_BGR2GRAY)
d = cv2.absdiff(gray1, gray2)
# print(np.sum(d))
plt.imshow(d, cmap='gray')
i += 1
# Out:
# 6058897

# %%
images_np = np.asarray(images)

# %%
time_array = np.linspace(0, 10*len(images_np), len(images_np)) / (60*60)

# %%
# len(time_array)
# len(images_np)
# time_array
# Out:
# array([0.00000000e+00, 2.77875587e-03, 5.55751174e-03, ...,
#        7.88610915e+00, 7.88888791e+00, 7.89166667e+00])

# %%
diff_array = []
for i in range(1,len(images_np)):
    gray1 = cv2.cvtColor(images[i], cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(images[i-1], cv2.COLOR_BGR2GRAY)
    d = cv2.absdiff(gray1, gray2)
    val = np.sum(d)
    diff_array.append(val)

# %%
diff_np = np.asarray(diff_array)

# %%
len(diff_np)
# Out:
# 2840

# %%
plt.plot(time_array[:-1], diff_np, 'b')
name = filenames[0][filenames[0].rfind('/')+1:-4]
plt.title('Sleep Movements over Time\nStart: ({})'.format(name))
plt.show()

# %%
import scipy.signal as signal

# %%
# First, design the Buterworth filter
N  = 2    # Filter order
Wn = 0.001 # Cutoff frequency
B, A = signal.butter(N, Wn, output='ba')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-283-75bce92175a3> in <module>()
#       2 N  = 2    # Filter order
#       3 Wn = 0.001 # Cutoff frequency
# ----> 4 B, A = signal.butter(N, [0, 10], output='ba')
#
# /usr/local/lib/python2.7/site-packages/scipy/signal/filter_design.pyc in butter(N, Wn, btype, analog, output)
#    2392     """
#    2393     return iirfilter(N, Wn, btype=btype, analog=analog,
# -> 2394                      output=output, ftype='butter')
#    2395
#    2396
#
# /usr/local/lib/python2.7/site-packages/scipy/signal/filter_design.pyc in iirfilter(N, Wn, rp, rs, btype, analog, ftype, output)
#    1957     if not analog:
#    1958         if numpy.any(Wn <= 0) or numpy.any(Wn >= 1):
# -> 1959             raise ValueError("Digital filter critical frequencies "
#    1960                              "must be 0 < Wn < 1")
#    1961         fs = 2.0
#
# ValueError: Digital filter critical frequencies must be 0 < Wn < 1

# %%
# Second, apply the filter
diff_filtered = signal.filtfilt(B,A,diff_np)

# %%
plt.plot(time_array[:-1], diff_filtered, 'b')
plt.title('Filtered Sleep Movements over Time')
plt.show()

# %%
plt.imshow(gray1)

# %%
plt.imshow(gray2)

# %%
d = cv2.absdiff(gray1,gray2)

# %%
plt.imshow(d)

# %%
img = cv2.cvtColor(images[0], cv2.COLOR_BGR2GRAY)

# %%
f = np.fft.fft2(img)

# %%
fshift = np.fft.fftshift(f)

# %%
magnitude_spectrum = 20*np.log(np.abs(fshift))

# %%
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
