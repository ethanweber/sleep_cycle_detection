# %%
import numpy as np
import cv2
import glob
import datetime
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pwd # under linux/mac
# Out:
# /Users/ethanweber/Documents/MIT_Classes/Sophomore_Spring2018/MAS.600/hackyodreamz/camera/webcam

# %%
cwd = "/Users/ethanweber/Documents/MIT_Classes/Sophomore_Spring2018/MAS.600/hackyodreamz/camera/webcam"

# %%
folder = "/data/4-30-2018_0"

# %%
path = cwd + folder

# %%
filenames = sorted(glob.glob(os.path.join(path,'*.png')))

# %%
images = []

# %%
for f in filenames:
    images.append(cv2.imread(f))

# %%
plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB), cmap='gray')

# %%
i = 0

# %%
gray1 = cv2.cvtColor(images[i], cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(images[i-1], cv2.COLOR_BGR2GRAY)
d = cv2.absdiff(gray1, gray2)
# print(np.sum(d))
plt.imshow(d, cmap='gray')
i += 1

# %%
images_np = np.asarray(images)

# %%
time_array = np.linspace(0, 10*len(images_np), len(images_np)) / (60*60)

# %%
# len(time_array)
# len(images_np)
# time_array

# %%
diff_array = []
for i in range(1,len(images_np)):
    gray1 = cv2.cvtColor(images[i], cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(images[i-1], cv2.COLOR_BGR2GRAY)
    d = cv2.absdiff(gray1, gray2)
    val = np.sum(d)
    diff_array.append(val)

# %%
diff_np = np.asarray(diff_array)

# %%
len(diff_np)
# Out:
# 1835

# %%
diff_norm = diff_np / np.max(diff_np)

# %%
plt.plot(time_array[10:-1], diff_np[10:], 'b')
name = filenames[0][filenames[0].rfind('/')+10:-4]
plt.title('Sleep Movements over Time\nStart: ({})'.format(name))
plt.ylabel("Image Difference Magnitude")
plt.xlabel("Hours")
plt.show()

# %%
import scipy.signal as signal

# %%
# First, design the Buterworth filter
N  = 2    # Filter order
Wn = 0.001 # Cutoff frequency
B, A = signal.butter(N, Wn, output='ba')

# %%
# Second, apply the filter
diff_filtered = signal.filtfilt(B,A,diff_np)

# %%
plt.plot(time_array[:-1], diff_filtered, 'b')
plt.title('Filtered Sleep Movements over Time')
plt.show()

# %%
plt.imshow(gray1)

# %%
plt.imshow(gray2)

# %%
d = cv2.absdiff(gray1,gray2)

# %%
plt.imshow(d)

# %%
img = cv2.cvtColor(images[0], cv2.COLOR_BGR2GRAY)

# %%
f = np.fft.fft2(img)

# %%
fshift = np.fft.fftshift(f)

# %%
magnitude_spectrum = 20*np.log(np.abs(fshift))

# %%
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# $$ x = \begin{bmatrix} x \\ y \end{bmatrix} $$

# %%
index = 0
for f in filenames:
    if f.find("03:42:12.868546") > 0:
        break
    index += 1

# %%
print(filenames[0])
# Out:
# /Users/ethanweber/Documents/MIT_Classes/Sophomore_Spring2018/MAS.600/hackyodreamz/camera/webcam/data/4-30-2018_0/2018-04-30_02:30:24.027792.png

# %%
index
# Out:
# 428

# %%
img = cv2.cvtColor(images[428], cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')

# %%
gray1 = cv2.cvtColor(images[428], cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(images[429], cv2.COLOR_BGR2GRAY)
d = cv2.absdiff(gray1, gray2)
print(np.sum(d))
plt.imshow(d, cmap='gray')
# Out:
# 27107739

# %%
gray1 = cv2.cvtColor(images[429], cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(images[430], cv2.COLOR_BGR2GRAY)
d = cv2.absdiff(gray1, gray2)
print(np.sum(d))
plt.imshow(d, cmap='gray')
# Out:
# 16491102
