# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read from a csv file
filename = '../records/2018-04-25 03:38:29.377676.csv'
data = np.genfromtxt(filename, delimiter=',')

# %%
len(data[:,0:2])
# Out:
# 3857

# %%
acc = data[4:,0:3]

# %%
time_array = data[4:,-1]

# %%
len(time_array)
# Out:
# 3853

# %%
mean_acc = acc

# %%
acc
# Out:
# array([[ 0.01, -0.13, -1.11],
#        [-0.  , -0.15, -1.11],
#        [ 0.01, -0.12, -1.11],
#        ...,
#        [-0.73,  0.62,  0.23],
#        [-0.73,  0.61,  0.23],
#        [-0.72,  0.6 ,  0.2 ]])

# %%
acc**2
# Out:
# array([[1.0000e-04, 1.6900e-02, 1.2321e+00],
#        [0.0000e+00, 2.2500e-02, 1.2321e+00],
#        [1.0000e-04, 1.4400e-02, 1.2321e+00],
#        ...,
#        [5.3290e-01, 3.8440e-01, 5.2900e-02],
#        [5.3290e-01, 3.7210e-01, 5.2900e-02],
#        [5.1840e-01, 3.6000e-01, 4.0000e-02]])

# %%
acc_mag = acc.sum(axis=1)

# %%
acc_mag
# Out:
# array([-1.23, -1.26, -1.22, ...,  0.12,  0.11,  0.08])

# %%
time_in_hours = time_array / (60*60)

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)
acc_x = data[4:,0]
acc_y = data[4:,1]
acc_z = data[4:,2]
# red dashes, blue squares and green triangles
plt.plot(time_in_hours, acc_x, 'r--', time_in_hours, acc_y, 'g--', time_in_hours, acc_z, 'b--')
plt.show()

# %%
gyro_x = data[4:,3]
gyro_y = data[4:,4]
gyro_z = data[4:,5]

# red dashes, blue squares and green triangles
plt.plot(time_in_hours, gyro_x, 'r--', time_in_hours, gyro_y, 'g--', time_in_hours, gyro_z, 'b--')
plt.show()

# %%
mag_x = data[4:,6]
mag_y = data[4:,7]
mag_z = data[4:,8]

# red dashes, blue squares and green triangles
plt.plot(time_in_hours, mag_x, 'r--', time_in_hours, mag_y, 'g--', time_in_hours, mag_z, 'b--')
plt.show()
